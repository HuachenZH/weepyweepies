# %%
import pandas as pd

# %%
df1 = pd.DataFrame({"A": [0, 1], "B":[2,3]})
df2 = pd.DataFrame({"A": [5, 6], "B":[7,8]})
df1
# Out:
#    A  B
# 0  0  2
# 1  1  3

# %%
df2
# Out:
#    A  B
# 0  5  7
# 1  6  8

# %%
pd.concat([df1, df2])
# Out:
#    A  B
# 0  0  2
# 1  1  3
# 0  5  7
# 1  6  8

# %%
# test concating empty dataframe
df_empty = pd.DataFrame({"A":[], "B":[]})
print(df_empty.empty)
pd.concat([df1, df_empty])
# Out:
# True
#      A    B
# 0  0.0  2.0
# 1  1.0  3.0

# %% [markdown]
# test pyvista

# %%
import numpy as np
import pyvista

point_cloud = np.random.random((100, 3))
pdata = pyvista.PolyData(point_cloud)
pdata['orig_sphere'] = np.arange(100)

# create many spheres from the point cloud
sphere = pyvista.Sphere(radius=0.02, phi_resolution=10, theta_resolution=10)
pc = pdata.glyph(scale=False, geom=sphere, orient=False)
pc.plot(cmap='Reds')
# Out:
# /home/huachen/.pyenv/versions/3.11.4/envs/weepyweepies/lib/python3.11/site-packages/pyvista/jupyter/notebook.py:34: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
